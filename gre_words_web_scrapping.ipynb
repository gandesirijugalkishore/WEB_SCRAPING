# %% [markdown]
# <a href="https://colab.research.google.com/github/gandesirijugalkishore/Web-scraping-and-parsing-with-BeautifulSoup-Python-/blob/master/gre_words_web_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.kaptest.com/study/gre/top-52-gre-vocabulary-words/"  #link for website
html = urlopen(url)
soup = BeautifulSoup(html, 'lxml')
type(soup)
title = soup.title
text = soup.get_text()

li=[]
word=soup.find("ol").find_all("li")
print(word[0])
# Out:
# <li><strong>anomaly</strong> – <em>noun</em> – something that is unusual or unexpected
# <ul>
# <li>The student’s poor performance on the latest test was an <strong>anomaly</strong> since she had previously earned excellent grades.</li>
# </ul>
# </li>

# %%
import datetime as dt
import time
import smtplib

def send_email():
    email_user = 'myemail@gmail.com'
    server = smtplib.SMTP ('smtp.gmail.com', 587)
    server.starttls()
    server.login(email_user, 'email pass')

    #EMAIL
    message = 'sending this from python!'
    server.sendmail(email_user, email_user, message)
    server.quit()

def send_email_at(send_time):
    time.sleep(send_time.timestamp() - time.time())
    send_email()
    print('email sent')

first_email_time = dt.datetime(2018,8,26,3,0,0) # set your sending time in UTC
interval = dt.timedelta(minutes=2*60) # set the interval for sending the email

send_time = first_email_time
while True:
    send_email_at(send_time)
    send_time = send_time + interval
# Out:
# (221, b'2.0.0 closing connection f131sm2552761pgc.14 - gsmtp')

# %%
i=0
new_list=[]
while i<len(li):
  new_list.append(li[i:i+3])
  i+=3
new_list
# Out:
# [['aberrant', 'adj.', 'deviating from \n          normal or correct.'],
#  ['abscond',
#   'v.',
#   'to leave secretly \n          and hide, often to avoid the law.'],
#  ['advocate',
#   'v., n.',
#   'to speak, plead, \n          or argue for a cause, or in another\x92s behalf. (n) -- one who advocates.'],
#  ['aggrandize',
#   'v.',
#   'to make greater, \n          to increase, thus, to exaggerate.'],
#  ['amalgamate', 'v.', 'to unite or mix. \n          (n) -- amalgamation.'],
#  ['ambiguous',
#   'adj.',
#   'vague; subject \n          to more than one interpretation'],
#  ['ambrosial',
#   'adj.',
#   'extremely pleasing \n          to the senses, divine (as related to the gods) or delicious (n: ambrosia)'],
#  ['anachronism',
#   'n.',
#   'a person or artifact \n          appearing after its own time or out of chronological order (adj: anachronistic)'],
#  ['anomalous',
#   'adj.',
#   'peculiar; unique, \n          contrary to the norm (n: anomaly)'],
#  ['antediluvian',
# ...
